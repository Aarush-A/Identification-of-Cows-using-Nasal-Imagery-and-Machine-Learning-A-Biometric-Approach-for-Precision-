# %%
import matplotlib.pyplot as plt

train_loss_50 = [49.3145, 13.3897, 3.3443, 2.4282, 1.2407, 1.5650, 0.1385, 0.3198, 0.1792, 0.1146, 4.7488e-05, 0.1344, 3.2247, 3.0063, 0.3845, 0.3064, 0.3457, 0.2124, 0.2038, 0.7180]

train_loss_25 = [28.8218, 18.7295, 8.3326, 3.1980, 1.6375, 1.1591, 1.2875, 0.1224, 0.1898, 0.0017, 0.0245, 0.0007, 0.2305, 6.2317e-06, 0.0640, 0.2268, 0.1202, 0.3197, 1.6755e-05, 0.0042]

epochs_50 = range(1, len(train_loss_50) + 1)
epochs_25 = range(1, len(train_loss_25) + 1)

plt.plot(epochs_50, train_loss_50, 'r', label='Training Loss (50 Classes)')

plt.plot(epochs_25, train_loss_25, 'g', label='Training Loss (25 Classes)')
plt.title('Training and Validation Loss Comparison')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Test and train accuracies for both datasets
train_acc_50 = [0.24784853700516352, 0.6006884681583476, 0.8433734939759037, 0.9001721170395869, 0.919104991394148, 0.9586919104991394, 0.9879518072289156, 0.9827882960413081, 0.9931153184165232, 0.9896729776247849, 1.0, 0.9913941480206541, 0.9156626506024096, 0.9208261617900172, 0.9724612736660929, 0.9793459552495697, 0.9879518072289156, 0.9879518072289156, 0.9879518072289156, 0.9690189328743546]
test_acc_50 = [0.07534246575342465, 0.07534246575342465, 0.10273972602739725, 0.2671232876712329, 0.6164383561643836, 0.7876712328767124, 0.8698630136986302, 0.8835616438356164, 0.8493150684931506, 0.9246575342465754, 0.910958904109589, 0.8424657534246576, 0.684931506849315, 0.8013698630136986, 0.8561643835616438, 0.952054794520548, 0.9041095890410958, 0.8972602739726028, 0.821917808219178, 0.8835616438356164]

train_acc_25 = [0.2680851063829787, 0.5617021276595745, 0.6723404255319149, 0.8595744680851064, 0.8851063829787233, 0.9276595744680851, 0.9617021276595744, 0.9829787234042553, 0.9829787234042553, 1.0, 0.9829787234042553, 1.0, 0.9829787234042553, 1.0, 0.9957446808510638, 0.9872340425531915, 0.9957446808510638, 0.9829787234042553, 1.0, 0.9957446808510638]
test_acc_25 =  [0.0821917808219178, 0.0410958904109589, 0.0410958904109589, 0.0410958904109589, 0.0410958904109589, 0.0821917808219178, 0.0821917808219178, 0.0958904109589041, 0.1232876712328767, 0.2602739726027397, 0.547945205479452, 0.684931506849315, 0.821917808219178, 0.8493150684931506, 0.8904109589041096, 0.9315068493150684, 0.9452054794520548, 0.9315068493150684, 0.9452054794520548, 0.9452054794520548]

# Set the figure size
plt.figure(figsize=(10, 6))

# Plot the train accuracies
plt.plot(train_acc_50, '-o', color='blue', label='50-class train', linewidth=2)
plt.plot(train_acc_25, '-o', color='green', label='25-class train', linewidth=2)

# Plot the test accuracies
plt.plot(test_acc_50, '-o', color='red', label='50-class test', linewidth=2)
plt.plot(test_acc_25, '-o', color='purple', label='25-class test', linewidth=2)

# Add labels and title
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.title('Comparison of Test and Train Accuracies', fontsize=16)

# Add xticks on the middle of the group bars
plt.xticks(range(len(test_acc_50)), [str(i) for i in range(len(test_acc_50))])

# Add a legend and show the graph
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Test and train accuracies for both datasets
train_acc_50 = [0.36660929432013767, 0.7108433734939759, 0.8795180722891566, 0.9208261617900172, 0.9672977624784854, 0.9569707401032702, 0.9690189328743546, 0.9690189328743546, 0.9655765920826161, 0.9724612736660929, 0.9913941480206541, 0.9913941480206541, 0.9982788296041308, 0.9948364888123924, 0.9948364888123924, 0.9982788296041308, 0.9965576592082617, 0.9948364888123924, 0.9586919104991394, 0.9414802065404475]
test_acc_50 = [0.0273972602739726, 0.15753424657534246, 0.2191780821917808, 0.4794520547945205, 0.4726027397260274, 0.8287671232876712, 0.9315068493150684, 0.8561643835616438, 0.726027397260274, 0.8698630136986302, 0.8698630136986302, 0.9246575342465754, 0.9178082191780822, 0.8972602739726028, 0.9315068493150684, 0.8972602739726028, 0.9383561643835616, 0.910958904109589, 0.8356164383561644, 0.678082191780822]

train_acc_25 = [0.217, 0.349, 0.626, 0.770, 0.838, 0.860, 0.940, 0.974, 0.966, 0.983, 0.996, 0.983, 0.991, 0.996, 1.0, 0.996, 0.996, 1.0, 1.0, 0.996]
test_acc_25 = [0.041, 0.247, 0.205, 0.288, 0.219, 0.164, 0.247, 0.260, 0.274, 0.411, 0.562, 0.795, 0.863, 0.918, 0.918, 0.945, 0.986, 0.986, 0.959, 0.931]
# Set the figure size
plt.figure(figsize=(10, 6))

# Plot the train accuracies
plt.plot(train_acc_50, '-o', color='blue', label='50-class train', linewidth=2)
plt.plot(train_acc_25, '-o', color='green', label='25-class train', linewidth=2)

# Plot the test accuracies
plt.plot(test_acc_50, '-o', color='red', label='50-class test', linewidth=2)
plt.plot(test_acc_25, '-o', color='purple', label='25-class test', linewidth=2)

# Add labels and title
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.title('Comparison of Test and Train Accuracies', fontsize=16)

# Add xticks on the middle of the group bars
plt.xticks(range(len(test_acc_50)), [str(i) for i in range(len(test_acc_50))])

# Add a legend and show the graph
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dataset 1
train_loss_1 = [29.0582, 28.6913, 19.5373, 12.2668, 5.5664, 3.3303, 0.8173, 0.1878, 0.2783, 0.4029, 0.0102, 0.4373, 0.1201, 0.0157, 7.1639e-05, 0.0097, 0.0949, 2.7539e-05, 3.8002e-05, 0.0443]
epochs_1 = range(1, len(train_loss_1) + 1)

# Dataset 2
train_loss_2 = [29.7074, 10.9155, 3.0576, 2.0643, 2.2676, 0.7356, 0.9183, 0.7389, 0.5859, 0.7208, 0.2293, 0.1724, 0.3061, 0.1685, 0.0524, 0.0263, 0.2265, 0.2189, 1.4061, 2.0421]

epochs_2 = range(1, len(train_loss_2) + 1)

plt.plot(epochs_1, train_loss_1, label='50 Classes')
plt.plot(epochs_2, train_loss_2, label='25 Classes')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# 25 Class Dataset
train_acc_25_cpu = [0.2680851063829787, 0.5617021276595745, 0.6723404255319149, 0.8595744680851064, 0.8851063829787233, 0.9276595744680851, 0.9617021276595744, 0.9829787234042553, 0.9829787234042553, 1.0, 0.9829787234042553, 1.0, 0.9829787234042553, 1.0, 0.9957446808510638, 0.9872340425531915, 0.9957446808510638, 0.9829787234042553, 1.0, 0.9957446808510638]

test_acc_25_cpu = [0.0821917808219178, 0.0410958904109589, 0.0410958904109589, 0.0410958904109589, 0.0410958904109589, 0.0821917808219178, 0.0821917808219178, 0.0958904109589041, 0.1232876712328767, 0.2602739726027397, 0.547945205479452, 0.684931506849315, 0.821917808219178, 0.8493150684931506, 0.8904109589041096, 0.9315068493150684, 0.9452054794520548, 0.9315068493150684, 0.9452054794520548, 0.9452054794520548]
train_acc_25_cuda = [0.217, 0.349, 0.626, 0.770, 0.838, 0.860, 0.940, 0.974, 0.966, 0.983, 0.996, 0.983, 0.991, 0.996, 1.0, 0.996, 0.996, 1.0, 1.0, 0.996]
test_acc_25_cuda = [0.041, 0.247, 0.205, 0.288, 0.219, 0.164, 0.247, 0.260, 0.274, 0.411, 0.562, 0.795, 0.863, 0.918, 0.918, 0.945, 0.986, 0.986, 0.959, 0.931]

plt.plot(train_acc_25_cpu, label='Train Accuracy - CPU')
plt.plot(test_acc_25_cpu, label='Test Accuracy - CPU')
plt.plot(train_acc_25_cuda, label='Train Accuracy - CUDA')
plt.plot(test_acc_25_cuda, label='Test Accuracy - CUDA')
plt.title('25 Class Dataset - Train/Test Accuracy Comparison (CPU vs CUDA)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


# 50 Class Dataset
train_acc_50_cpu = [0.24784853700516352, 0.6006884681583476, 0.8433734939759037, 0.9001721170395869, 0.919104991394148, 0.9586919104991394, 0.9879518072289156, 0.9827882960413081, 0.9931153184165232, 0.9896729776247849, 1.0, 0.9913941480206541, 0.9156626506024096, 0.9208261617900172, 0.9724612736660929, 0.9793459552495697, 0.9879518072289156, 0.9879518072289156, 0.9879518072289156, 0.9690189328743546]
test_acc_50_cpu = [0.07534246575342465, 0.07534246575342465, 0.10273972602739725, 0.2671232876712329, 0.6164383561643836, 0.7876712328767124, 0.8698630136986302, 0.8835616438356164, 0.8493150684931506, 0.9246575342465754, 0.910958904109589, 0.8424657534246576, 0.684931506849315, 0.8013698630136986, 0.8561643835616438, 0.952054794520548, 0.9041095890410958, 0.8972602739726028, 0.821917808219178, 0.8835616438356164]
train_acc_50_cuda= [0.36660929432013767, 0.7108433734939759, 0.8795180722891566, 0.9208261617900172, 0.9672977624784854, 0.9569707401032702, 0.9690189328743546, 0.9690189328743546, 0.9655765920826161, 0.9724612736660929, 0.9913941480206541, 0.9913941480206541, 0.9982788296041308, 0.9948364888123924, 0.9948364888123924, 0.9982788296041308, 0.9965576592082617, 0.9948364888123924, 0.9586919104991394, 0.9414802065404475]
test_acc_50_cuda = [0.0273972602739726, 0.15753424657534246, 0.2191780821917808, 0.4794520547945205, 0.4726027397260274, 0.8287671232876712, 0.9315068493150684, 0.8561643835616438, 0.726027397260274, 0.8698630136986302, 0.8698630136986302, 0.9246575342465754, 0.9178082191780822, 0.8972602739726028, 0.9315068493150684, 0.8972602739726028, 0.9383561643835616, 0.910958904109589, 0.8356164383561644, 0.678082191780822]


plt.plot(train_acc_50_cpu, label='Train Accuracy - CPU')
plt.plot(test_acc_50_cpu, label='Test Accuracy - CPU')
plt.plot(train_acc_50_cuda, label='Train Accuracy - CUDA')
plt.plot(test_acc_50_cuda, label='Test Accuracy - CUDA')
plt.title('50 Class Dataset - Train/Test Accuracy Comparison (CPU vs CUDA)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()



plt.plot(train_acc_50_cpu, label='Train Accuracy 50 Class - CPU')
plt.plot(test_acc_50_cpu, label='Test Accuracy 50 Class - CPU')
plt.plot(train_acc_50_cuda, label='Train Accuracy 50 Class - CUDA')
plt.plot(test_acc_50_cuda, label='Test Accuracy 50 Class - CUDA')
plt.plot(train_acc_25_cpu, label='Train Accuracy 25 Class- CPU')
plt.plot(test_acc_25_cpu, label='Test Accuracy 25 Class - CPU')
plt.plot(train_acc_25_cuda, label='Train Accuracy 25 Class - CUDA')
plt.plot(test_acc_25_cuda, label='Test Accuracy 25 Class - CUDA')
plt.title('Train/Test Accuracy Comparison (CPU vs CUDA)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
